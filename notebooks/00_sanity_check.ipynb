# %%
from pathlib import Path
import pandas as pd

cic_raw = Path("data/cicids2017/raw")
unsw_raw = Path("data/unsw-nb15/raw")

list(cic_raw.glob("*.csv"))[:5], list(unsw_raw.glob("*.csv"))[:5]
# Out:
# ([], [])

# %%
cic_files = sorted(cic_raw.glob("*.csv"))
df_cic_small = pd.read_csv(cic_files[0], nrows=1000)
df_cic_small.head()
df_cic_small["Label"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 cic_files = sorted(cic_raw.glob("*.csv"))
# ----> 2 df_cic_small = pd.read_csv(cic_files[0], nrows=1000)
#       3 df_cic_small.head()
#       4 df_cic_small["Label"].value_counts()
#
# IndexError: list index out of range
